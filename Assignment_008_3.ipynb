# %% [markdown]
# <a href="https://colab.research.google.com/github/AzizOzmen/Clarusway_Assignments/blob/main/Assignment_008_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **💡Objective:**
#
# To improve your control flow statement and arithmetic operator algorithm skills.
# Write your Python codes on any IDE, push it up to your GitHub repository and submit your GitHub Page link address in addition to your code as a plain text.
#
# **Task:**
#
# Find out if a given number is an "Armstrong Number".
#
# An n-digit number that is the sum of the nth powers of its digits is called an n-Armstrong number. Examples :
#
# 371 = 33 + 73 + 13;
#
# 9474 = 94 + 44 + 74 + 44;
#
# 93084 = 95 + 35 + 05 + 85 + 45.
#
# Write a Python program that;
#
# 1- takes a positive integer number from the user,
#
# 2- checks the entered number if it is Armstrong,
#
# 3- consider the negative, float and any entries other than numeric values then display a warning message to the user.
#
# **Examples**
#
# ![Capture1.PNG](data:image/png;base64,...)
#
# **Note that;** this question is famous on the web, so that do it yourself to get more benefits from it. By the way, do not use try - except block.

# %%
while True:
  num = input("Please enter a positive number: ")
  if num.isdecimal() and int(num) > 0:
    num_list = list(num)
    exp = len(num)
    sum = 0
    for i in num_list:
      sum += int(i) ** exp
    if toplam == int(num):
      print(f"{num} is an Armstrong number.")
    else:
      print(f"{num} is not an Armstrong number.")
    break
  else:
    print("It is an invalid entry. Don't use non-numeric, float, or negative values!")
# Out:
# Please enter a positive number: 1.3
# It is an invalid entry. Don't use non-numeric, float, or negative values!
# Please enter a positive number: -5
# It is an invalid entry. Don't use non-numeric, float, or negative values!
# Please enter a positive number: 407
# 407 is an Armstrong number.

# %%
while True:
    num = input("Please enter a number: ")
    if num.isdecimal() and int(num) > 0:
        num_list = list(num)
        exp = len(num)
        toplam = 0
        for i in num_list:
            toplam += int(i) ** exp
        if toplam == int(num):
            print(f"{num} is an Armstrong number.")
        else:
            print(f"{num} is not an Armstrong number.")
        break
    else:
        print("Please enter a positive number as int")

# %%
sum = 0

num = input("Please enter a positive number: ")
num1 = int(float(num))

for i in num:
  if (i.isdecimal()) and num1 > 0:
    sum += int(i)**(len(num))
    if sum == num:
      print(f"{num} is an Armstrong number.")
      
    else:
      print(f"{num} is an NOT Armstrong number.")
      break
  else:
    print("It is an invalid entry. Don't use non-numeric, float, or negative values!")
    break
# Out:
# Please enter a positive number: 407
# 407 is an NOT Armstrong number.
# 407 is an NOT Armstrong number.
# 407 is an NOT Armstrong number.

# %% [markdown]
# There are two methods isdigit() and isnumeric() that checks whether the string contains digit characters and numeric characters respectively.

# %%
x = "457836"
y = "407.7"
print(len(x))
print(len(y))

print(x.isdigit())
print(x.isdecimal())
print(x.isnumeric())
print()
print(y.isdigit())
print(y.isdecimal())
print(y.isnumeric())
# Out:
# 6
# 5
# True
# True
# True
#
# False
# False
# False

# %%
# Python program to find the sum of all numbers present in the string
# Function to find the sum of all numbers in the string
def findSum(str1):
	temp = ""  # initialize temp
	sum = 0  #initialize sum
	for ch in str1:  # Traverse the characters one by one
		if (ch.isdigit()):   # if the character is a sigit
			temp += ch  # add that char to the string temp
		else:
			sum = sum + int(temp)  # find the sum of all numbers in string temp
			temp = "0"
return sum + int(temp)  # return the sum

str1 = input("Enter the string : ")
print(findSum(str1))

# %%
num = int(input("Enter a positive number: "))  

order = len(str(num))
sum = 0

temp = num
while temp > 0:
   first_digit = temp % 10  # gives the first digit on the right at each loop
   sum += first_digit ** order
   temp //= 10

# display the result if num is Armstrong number or not

if num > 0:
  if num == sum:
    print(num,"is an Armstrong number")  
  else:  
    print(num,"is not an Armstrong number")
else:
  print("It's invalid entry. Don't use non-numeric, float or negative values!")

# %%
num = int(input("Enter a positive number: "))  

# we need to change num variable to string for calculating the length (number of digits)
order = len(str(num))

# initialize sum
sum = 0

# we need to find the sum of the nth (the length of num here) powers of each digit 
temp = num
while temp > 0:
   digit = temp % 10  # gives the first digit on the right at each loop
   sum += digit ** order
   temp //= 10

# display the result if num is Armstrong number or not

if num > 0:
  if num == sum:
    print(num,"is an Armstrong number")  
  else:  
    print(num,"is not an Armstrong number")
else:
  print("It's invalid entry. Don't use non-numeric, float or negative values!")
# Out:
# Enter a positive number: 12.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-20ca22cbb428> in <module>()
# ----> 1 num = int(input("Enter a positive number: "))
#       2
#       3 # we need to change num variable to string for calculating the length (number of digits)
#       4 order = len(str(num))
#       5
#
# ValueError: invalid literal for int() with base 10: '12.3'

# %%
num = int(input("Enter a positive number: "))  

# we need to change num variable to string for calculating the length (number of digits)
order = len(str(num))

# initialize sum
sum = 0

# we need to find the sum of the nth (the length of num here) powers of each digit 
temp = num
while temp > 0:
   digit = temp % 10  # gives the first digit on the right at each loop
   sum += digit ** order
   temp //= 10

# display the result if num is Armstrong number or not
if num > 0 and not (num == int):
  if num == sum:
    print(num,"is an Armstrong number")  
  else:  
    print(num,"is not an Armstrong number")
else:
  print("It's invalid entry. Don't use non-numeric, float or negative values!")
# Out:
# Enter a positive number: 10.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-c42ab99510c2> in <module>()
# ----> 1 num = int(input("Enter a positive number: "))
#       2
#       3 # we need to change num variable to string for calculating the length (number of digits)
#       4 order = len(str(num))
#       5
#
# ValueError: invalid literal for int() with base 10: '10.2'

# %%
num = int(input("Enter a positive number: "))  

# we need to change num variable to string for calculating the length (number of digits)
order = len(str(num))

# initialize sum
sum = 0

# we need to find the sum of the nth (the length of num here) powers of each digit 
temp = num
while temp > 0:
   digit = temp % 10  # gives the first digit on the right at each loop
   sum += digit ** order
   temp //= 10

# display the result if num is Armstrong number or not

if isinstance(num, int):
  pass
elif num > 0:
  if num == sum:
    print(num,"is an Armstrong number")  
  else:  
    print(num,"is not an Armstrong number")
else:
  print("It's invalid entry. Don't use non-numeric, float or negative values!")
# Out:
# Enter a positive number: 12.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-8d6b858a7250> in <module>()
# ----> 1 num = int(input("Enter a positive number: "))
#       2
#       3 # we need to change num variable to string for calculating the length (number of digits)
#       4 order = len(str(num))
#       5
#
# ValueError: invalid literal for int() with base 10: '12.3'

# %%
num = input("Enter a positive number: ")  
print(len(num))  # since the input str, len() method worked, otherwise (int) not.
# Out:
# Enter a positive number: 4521
# 4

# %%
407//10
# Out:
# 40

# %%
407%10
# Out:
# 7

# %%
40%10
# Out:
# 0

# %%
7**3
# Out:
# 343

# %%
0**3
# Out:
# 0

# %%
4**3
# Out:
# 64

# %%
343+64
# Out:
# 407

# %%
def armstrong_number():
    for i in range(0,1):
        sayi=int(input("Lütfen bir sayı giriniz : "))
        if sayi<=0:
            print("pozitif bir sayı giriniz.")
            break
        elif sayi>0:
            basamak=len(str(sayi))
            if basamak==1:
                print("Tek basamklı sayı giremessiniz.")
                break
            elif basamak>1:
                toplam=0
                for i in str(sayi):
                    toplam=toplam+(int(i)**basamak)
                print(f"sayıların rakamlara ayırıp basamak sayısı kadar üssünü alıp toplayınca çıkan sonuç = {toplam}")
                if toplam==sayi:
                    print(f"Girilen sayi = {sayi} bir amstrong sayısıdır.")
                elif toplam!=sayi:
                    print(f"Girilen sayi = {sayi} bir amstrong sayısı değildir.")
armstrong_number()
# Out:
# Lütfen bir sayı giriniz : one
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-d9b3d4de0eb6> in <module>()
#      19                 elif toplam!=sayi:
#      20                     print(f"Girilen sayi = {sayi} bir amstrong sayısı değildir.")
# ---> 21 armstrong_number()
#
# <ipython-input-42-d9b3d4de0eb6> in armstrong_number()
#       1 def armstrong_number():
#       2     for i in range(0,1):
# ----> 3         sayi=int(input("Lütfen bir sayı giriniz : "))
#       4         if sayi<=0:
#       5             print("pozitif bir sayı giriniz.")
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
intchecker = float(input('Please enter a integer: '))
intcheck = 0
while intcheck != 1:
    if intchecker - int(intchecker) > 0:
        intchecker = float(input("You didn't enter a integer. "
                                 "Please enter a integer: "))
    else:
        intcheck = 1
print('you have entered a integer')
# Out:
# Please enter a integer: 5.4
# You didn't enter a integer. Please enter a integer: 5
# you have entered a integer

# %%
intchecker = float(input('Please enter a integer: '))
intcheck = intchecker - (int(intchecker))
if intchecker - int(intchecker) > 0:
  print("You didn't enter a integer.")
                          
else:
  print('you have entered a integer')
# Out:
# Please enter a integer: 3
# you have entered a integer
